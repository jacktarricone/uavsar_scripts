# %%
import xarray as xr
import rioxarray as rxr
import numpy as np
import hvplot.xarray  # noqa
from matplotlib import pyplot as plt

# %%
hdf5file = "/Volumes/JT/projects/margulis/static/rasters/SNSR_DEM.tif"

dem = xr.open_dataset(hdf5file, engine="rasterio").load()
dem.transpose("band","y","x"
# Out:
# <xarray.Dataset>
# Dimensions:      (band: 1, x: 5701, y: 6601)
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 -123.3 -123.3 -123.3 ... -117.6 -117.6 -117.6
#   * y            (y) float64 42.0 42.0 42.0 42.0 42.0 ... 35.4 35.4 35.4 35.4
#     spatial_ref  int64 0
# Data variables:
#     band_data    (band, y, x) float32 nan nan nan nan nan ... nan nan nan nan

# %%
test = np.DataArray(dem)
plt.imshow(test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/7d/61kbxptj5yl29nbrh216cv_40000gn/T/ipykernel_2200/4019963823.py in <module>
# ----> 1 test = np.DataArray(dem)
#       2 plt.imshow(test)
#
# ~/opt/miniconda3/envs/test_env/lib/python3.8/site-packages/numpy/__init__.py in __getattr__(attr)
#     311                 return Tester
#     312
# --> 313             raise AttributeError("module {!r} has no attribute "
#     314                                  "{!r}".format(__name__, attr))
#     315
#
# AttributeError: module 'numpy' has no attribute 'DataArray'
